# %% [markdown]
# <a href="https://colab.research.google.com/github/Omara455/Machine-Learning-Journey/blob/main/AI_Engineer_Salary_Simple_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Import Dataset

# %%
dataset = pd.read_csv('ai_engineer_salaries.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
#   Check if there is line, is it worth using simple regression?

# %%
plt.scatter(X, y, color = 'red')
plt.title('Salary vs Experience (Test set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %% [markdown]
# Splitting Training and Test

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# Train Model With Data

# %%
from sklearn.linear_model import LinearRegression
regr = LinearRegression()
regr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Predict Test Results

# %%
y_pred = regr.predict(X_test)
y_pred
# Out:
# array([106181.8312575 , 143581.46579124,  55959.46488363,  96564.7823774 ,
#        120073.12408432,  97633.34336407, 114730.31915093,  63439.39179037,
#         75193.56264383,  62370.83080369])

# %% [markdown]
# Compare Actual vs Predicted

# %%
df_comparison = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
print(df_comparison)
# Out:
#      Actual      Predicted
# 0  113293.0  106181.831257
# 1  149319.0  143581.465791
# 2   95000.0   55959.464884
# 3  102457.0   96564.782377
# 4  125075.0  120073.124084
# 5  108828.0   97633.343364
# 6  120734.0  114730.319151
# 7   74704.0   63439.391790
# 8   66749.0   75193.562644
# 9   49372.0   62370.830804

# %% [markdown]
# Visualize Training Set

# %%
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, regr.predict(X_train), color = 'blue')
plt.title('Salary vs Experience (Training set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %% [markdown]
# Visualize Test Set

# %%
plt.scatter(X_test, y_test, color = 'red')
plt.plot(X_train , regr.predict(X_train), color = 'blue')
plt.title('Salary vs Experience (Test set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')
