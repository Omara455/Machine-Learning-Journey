# %% [markdown]
# <a href="https://colab.research.google.com/github/Omara455/Machine-Learning-Journey/blob/main/Speed_Stopping_Distance_Poly_%20Regression(Non_Categorical_Data).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('speed_stopping_distance.csv')
X = dataset.iloc[:, :-1].values # put 1:-1 to check if worth using poly regression (if using more than one numerical column), if worth put back [:, :-1]
y = dataset.iloc[:, -1].values

# %% [markdown]
# ## Check whether poly regression is worth it

# %%
# plt.scatter(X, y, color = 'red')
# plt.title('Salary vs Experience (Test set)')
# plt.xlabel('Speed_mph')
# plt.ylabel('Stopping_distance')

# %% [markdown]
# ## Training the Polynomial Regression model on the whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Visualising the Polynomial Regression results

# %%
plt.scatter(X, y, color = 'red')
plt.plot(X, lin_reg_2.predict(poly_reg.fit_transform(X)), color = 'blue')
plt.title('Truth or Bluff (Polynomial Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Predicting a new result with Polynomial Regression

# %%
lin_reg_2.predict(poly_reg.fit_transform([[20]]))
# Out:
# array([48.9643969])
